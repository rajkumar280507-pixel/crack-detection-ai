# %% [markdown]
# # AI-Based Structural Crack Detection
# ## Convolutional Neural Network (CNN) Training
#
# This notebook demonstrates the training process for the Crack Detection model. We use the Concrete Crack Images dataset to classify images as 'Crack' or 'Non-Crack'.

# %%
import os
import sys
sys.path.append('..')

import tensorflow as tf
from src.train_model import build_model, train

print("TensorFlow version:", tf.__version__)

# %% [markdown]
# ### 1. Data Preparation
# We split the data into training and validation sets. Data augmentation is used to improve model generalization.

# %%
dataset_path = '../dataset'
model_path = '../models/model.h5'

# Note: In a real scenario, you would populate the dataset folder with real images.
# The training script will generate synthetic data if the folder is empty.

# %% [markdown]
# ### 2. Model Architecture
# We use a sequence of Convolutional layers followed by Max Pooling and Dense layers.

# %%
model = build_model()
model.summary()

# %% [markdown]
# ### 3. Training
# Run the training process.

# %%
train(dataset_path, model_path)
